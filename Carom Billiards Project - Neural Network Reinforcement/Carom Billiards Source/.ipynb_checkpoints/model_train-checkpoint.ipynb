# %%
from keras.models import load_model, Sequential, save_model
from keras.layers import Dense, Dropout
import h5py
import numpy as np
# Out:
# c:\users\mrinal\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_inputs = np.load('training_data/train_inputs_para_30.npy')

# %%
train_targets = np.load('training_data/train_targets_para_30.npy')

# %%
len(train_inputs)
# Out:
# 6997003

# %%
len(train_targets)
# Out:
# 6997003

# %%
model = Sequential()
model.add(Dense(8, input_dim=8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(300, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(200, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='relu'))

model.compile(loss='mean_squared_error', optimizer='nadam', metrics=['accuracy'])

# %%
history = model.fit(train_inputs, train_targets, validation_split=0.2, epochs = 110, batch_size = 10000)
# Out:
# Train on 5597602 samples, validate on 1399401 samples
# Epoch 1/110
# 5597602/5597602 [==============================] - 16s 3us/step - loss: 317.0253 - acc: 0.0363 - val_loss: 303.3242 - val_acc: 0.0325
# Epoch 2/110
# 5597602/5597602 [==============================] - 15s 3us/step - loss: 299.5466 - acc: 0.0342 - val_loss: 289.4913 - val_acc: 0.0490
# Epoch 3/110
# 5597602/5597602 [==============================] - 16s 3us/step - loss: 284.4955 - acc: 0.0578 - val_loss: 276.3609 - val_acc: 0.0572
# Epoch 4/110
# 5597602/5597602 [==============================] - 15s 3us/step - loss: 278.1874 - acc: 0.0345 - val_loss: 271.8482 - val_acc: 0.0353
# Epoch 5/110
# 5597602/5597602 [==============================] - 15s 3us/step - loss: 274.9405 - acc: 0.0340 - val_loss: 277.2515 - val_acc: 0.0350
# Epoch 6/110
# 5597602/5597602 [==============================] - 15s 3us/step - loss: 271.5323 - acc: 0.0672 - val_loss: 266.4866 - val_acc: 0.1461
# Epoch 7/110
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Reinforcement Training

# %%
train_inputs = np.load('training_data/reinforced_inputs_size_30_v1.npy')
train_targets = np.load('training_data/reinforced_targets_size_30_v1.npy')

# %%
history = model.fit(train_inputs, train_targets, validation_split=0.1, epochs = 110, batch_size = 500)
# Out:
# Train on 98990 samples, validate on 10999 samples
# Epoch 1/110
# 98990/98990 [==============================] - 2s 16us/step - loss: 1228.5250 - acc: 0.2488 - val_loss: 1467.1962 - val_acc: 0.0925
# Epoch 2/110
# 98990/98990 [==============================] - 2s 17us/step - loss: 1110.3110 - acc: 0.2943 - val_loss: 1427.5787 - val_acc: 0.0938
# Epoch 3/110
# 98990/98990 [==============================] - 2s 17us/step - loss: 1085.6029 - acc: 0.2999 - val_loss: 1426.1686 - val_acc: 0.0020
# Epoch 4/110
# 98990/98990 [==============================] - 2s 17us/step - loss: 1076.8112 - acc: 0.3014 - val_loss: 1438.0698 - val_acc: 0.0933
# Epoch 5/110
# 98990/98990 [==============================] - 2s 16us/step - loss: 1063.6921 - acc: 0.3016 - val_loss: 1403.2037 - val_acc: 0.0926
# Epoch 6/110
# 98990/98990 [==============================] - 2s 17us/step - loss: 1054.2977 - acc: 0.3029 - val_loss: 1386.3240 - val_acc: 0.0929
# Epoch 7/110
# ...

# %%
save_model(model, 'models/reinforced_ball_size_30_light_v2.h5')
